# %% [markdown]
# # Bash

# %% [markdown]
# ***
# ###

# %% [markdown]
# - quant.txt was generated by CLEAR(CIRCexplorer3) using PA1 cell ribo– RNA-seq data (GEO:GSE73325)

# %%
# circRNA derived from back-spliced exons

awk '$14=="circRNA"' 00_PA1_steady_ribominus_rep1_quant.txt > 01_PA1_steady_ribominus_rep1_circRNA.txt
awk '$14=="circRNA"' 00_PA1_steady_ribominus_rep2_quant.txt > 01_PA1_steady_ribominus_rep2_circRNA.txt

# %%
# ciRNA derived from intron lariat

awk '$14=="ciRNA"' 00_PA1_steady_ribominus_rep1_quant.txt > 01_PA1_steady_ribominus_rep1_ciRNA.txt
awk '$14=="ciRNA"' 00_PA1_steady_ribominus_rep2_quant.txt > 01_PA1_steady_ribominus_rep2_ciRNA.txt
